# %%
from bravado.client import SwaggerClient

cbioportal = SwaggerClient.from_url('https://www.cbioportal.org/api/v2/api-docs',
                                config={"validate_requests":False,"validate_responses":False,"validate_swagger_spec":False})
print(cbioportal)
# Out:
# SwaggerClient(https://www.cbioportal.org/api)

# %%
import pandas as pd

# %%
for a in dir(cbioportal):
    cbioportal.__setattr__(a.replace(' ', '_').lower(), cbioportal.__getattr__(a))#

# %%
cancerTypeId = "cllsll"

# %%
# cll = cbioportal.Cancer_Types.getCancerTypeUsingGET(cancerTypeId).result()
# print(cll)

# %%
dir(cbioportal.Studies)
# Out:
# ['fetchStudiesUsingPOST',
#  'getAllStudiesUsingGET',
#  'getStudyUsingGET',
#  'getTagsForMultipleStudiesUsingPOST',
#  'getTagsUsingGET']

# %%
all_studies = cbioportal.Studies.getAllStudiesUsingGET().result()
cll_studies = [s for s in all_studies if s.cancerTypeId == cancerTypeId]

# %%
cll_studies
# Out:
# [CancerStudy(allSampleCount=105, cancerType=None, cancerTypeId='cllsll', citation='Quesada et al. Nature Genetics 2011', cnaSampleCount=None, completeSampleCount=None, description='Whole-exome sequencing of 105 Chronic Lymphocytic Leukemia samples.', groups='PUBLIC', importDate='2024-12-04 11:30:41', massSpectrometrySampleCount=None, methylationHm27SampleCount=None, miRnaSampleCount=None, mrnaMicroarraySampleCount=None, mrnaRnaSeqSampleCount=None, mrnaRnaSeqV2SampleCount=None, name='Chronic lymphocytic leukemia (ICGC, Nature Genetics 2011)', pmid='22158541', publicStudy=True, readPermission=True, referenceGenome='hg19', rppaSampleCount=None, sequencedSampleCount=None, status=0, studyId='cllsll_icgc_2011', treatmentCount=None),
#  CancerStudy(allSampleCount=160, cancerType=None, cancerTypeId='cllsll', citation='Landau et al. Cell 2013', cnaSampleCount=None, completeSampleCount=None, description='Whole-exome sequencing of 160 CLL tumor/normal pairs.', groups='', importDate='2024-12-05 13:26:10', massSpectrometrySampleCount=None, methylationHm27SampleCount=None, miRnaSampleCount=None, mrnaMicroarraySampleCount=None, mrnaRnaSeqSampleCount=None, mrnaRnaSeqV2SampleCount=None, name='Chronic Lymphocytic Leukemia (Broad, Cell 2013)', pmid='23415222', publicStudy=True, readPermission=True, referenceGenome='hg19', rppaSampleCount=None, sequencedSampleCount=None, status=0, studyId='lcll_broad_2013', treatmentCount=None),
#  CancerStudy(allSampleCount=506, cancerType=None, cancerTypeId='cllsll', citation='Puente et al. Nature 2015', cnaSampleCount=None, completeSampleCount=None, description='Mutation data from whole-genome or whole-exome sequencing of 428 CLL, 54 MBL, and 24 SLL tumor/normal pairs.', groups='', importDate='2024-12-20 02:53:22', massSpectrometrySampleCount=None, methylationHm27SampleCount=None, miRnaSampleCount=None, mrnaMicroarraySampleCount=None, mrnaRnaSeqSampleCount=None, mrnaRnaSeqV2SampleCount=None, name='Chronic Lymphocytic Leukemia (IUOPA, Nature 2015)', pmid='26200345', publicStudy=True, readPermission=True, referenceGenome='hg19', rppaSampleCount=None, sequencedSampleCount=None, status=0, studyId='cll_iuopa_2015', treatmentCount=None),
#  CancerStudy(allSampleCount=537, cancerType=None, cancerTypeId='cllsll', citation='Landau et al. Nature 2015', cnaSampleCount=None, completeSampleCount=None, description='Whole exome sequencing of 537 chronic lymphocytic leukemia tumor/normal pairs.', groups='PUBLIC', importDate='2024-12-20 04:09:27', massSpectrometrySampleCount=None, methylationHm27SampleCount=None, miRnaSampleCount=None, mrnaMicroarraySampleCount=None, mrnaRnaSeqSampleCount=None, mrnaRnaSeqV2SampleCount=None, name='Chronic Lymphocytic Leukemia (Broad, Nature 2015)', pmid='26466571', publicStudy=True, readPermission=True, referenceGenome='hg19', rppaSampleCount=None, sequencedSampleCount=None, status=0, studyId='cll_broad_2015', treatmentCount=None),
#  CancerStudy(allSampleCount=1154, cancerType=None, cancerTypeId='cllsll', citation='Knisbacher et al. Nature 2022', cnaSampleCount=None, completeSampleCount=None, description='Whole genome and whole exome sequencing of 1,154 samples from 1,148 patients with Chronic Lymphocytic Leukemia and monoclonal B cell lymphocytosis and their matched normals.', groups='', importDate='2024-12-20 11:07:33', massSpectrometrySampleCount=None, methylationHm27SampleCount=None, miRnaSampleCount=None, mrnaMicroarraySampleCount=None, mrnaRnaSeqSampleCount=None, mrnaRnaSeqV2SampleCount=None, name='Chronic Lymphocytic Leukemia (Broad, Nature Genetics 2022)', pmid='35927489', publicStudy=True, readPermission=True, referenceGenome='hg19', rppaSampleCount=None, sequencedSampleCount=None, status=0, studyId='cll_broad_2022', treatmentCount=None)]

# %%
total_samples = 0
for study in cll_studies:
    total_samples += study.allSampleCount
    print(study.studyId, study.description, study.allSampleCount)
print("Total samples:", total_samples)
# Out:
# cllsll_icgc_2011 Whole-exome sequencing of 105 Chronic Lymphocytic Leukemia samples. 105
# lcll_broad_2013 Whole-exome sequencing of 160 CLL tumor/normal pairs. 160
# cll_iuopa_2015 Mutation data from whole-genome or whole-exome sequencing of 428 CLL, 54 MBL, and 24 SLL tumor/normal pairs. 506
# cll_broad_2015 Whole exome sequencing of 537 chronic lymphocytic leukemia tumor/normal pairs. 537
# cll_broad_2022 Whole genome and whole exome sequencing of 1,154 samples from 1,148 patients with Chronic Lymphocytic Leukemia and monoclonal B cell lymphocytosis and their matched normals. 1154
# Total samples: 2462

# %%
def write_df_to_csv(filename, df):
    df.to_csv(filename, index=False)
    print(f"Data written to {filename}")

# %% [markdown]
# ## Clinical data

# %%
def get_data_for_study(studyId):

    clinical_data_sample = cbioportal.Clinical_Data.getAllClinicalDataInStudyUsingGET(
        studyId=studyId,
        projection="DETAILED",
        clinicalDataType="SAMPLE"
    ).result()

    clinical_data_patient = cbioportal.Clinical_Data.getAllClinicalDataInStudyUsingGET(
        studyId=studyId,
        projection="DETAILED",
        clinicalDataType="PATIENT"
    ).result()

    csdf = pd.DataFrame.from_dict([
        # python magic that combines two dictionaries:
        dict(
            {k:getattr(m,k) for k in dir(m)},
        )
        # create one item in the list for each mutation
        for m in clinical_data_sample
    ])
    cpdf = pd.DataFrame.from_dict([
        # python magic that combines two dictionaries:
        dict(
            {k:getattr(m,k) for k in dir(m)},
        )
        # create one item in the list for each mutation
        for m in clinical_data_patient
    ])


    cpdf.drop(columns=['clinicalAttribute'], inplace=True)
    csdf.drop(columns=['clinicalAttribute'], inplace=True)


    mutations = cbioportal.Mutations.getMutationsInMolecularProfileBySampleListIdUsingGET(
        molecularProfileId=f'{studyId}_mutations',
        sampleListId=f'{studyId}_all',
        projection='DETAILED'
    ).result()

    mdf = pd.DataFrame.from_dict([
    # python magic that combines two dictionaries:
        dict(
            {k:getattr(m,k) for k in dir(m)},
            **{k:getattr(m.gene,k) for k in dir(m.gene)}) 
        # create one item in the list for each mutation
        for m in mutations
    ])
    mdf.drop(columns=['gene', 'uniquePatientKey', 'uniqueSampleKey'], inplace=True)

    return cpdf, csdf, mdf

# %%
# using these 2 dataframes, i want to create a df with patient id, sample id, age, sex (all clinicalattributeid from cpdf), CANCER_TYPE, (all clinicalattributeid from csdf)
def process_patient_sample_data(cpdf, csdf):
    # display(cpdf[cpdf.patientId == 'P-CRC-0001'])
    # display(csdf[csdf.patientId == 'P-CRC-0001'])
    pivot_patient_df = cpdf.pivot(index='patientId', columns='clinicalAttributeId', values='value').reset_index()
    pivot_sample_df = csdf.pivot(index=['patientId', 'sampleId', 'studyId'], columns='clinicalAttributeId', values='value').reset_index()
    df = pivot_sample_df.merge(pivot_patient_df, on='patientId', how='left')
    return df

# %%
def process_study(studyId):
    cpdf, csdf, mdf = get_data_for_study(studyId)
    df = process_patient_sample_data(cpdf, csdf)
    print(df.shape, df.columns)
    display(df.head())
    print(mdf.shape, mdf.columns)
    display(mdf.head())

    # drop columsn where all values are null
    df.dropna(axis=1, how='all', inplace=True)
    mdf.dropna(axis=1, how='all', inplace=True)

    write_df_to_csv(f'../../data/cbioportal/{studyId}_clinical_data.csv', df)
    write_df_to_csv(f'../../data/cbioportal/{studyId}_mutations.csv', mdf)

# %%
def driver():
    for study in cll_studies:
        studyId = study.studyId
        print(studyId)
        process_study(studyId)

# %%
driver()
# Out:
# cllsll_icgc_2011
# (105, 10) Index(['patientId', 'sampleId', 'studyId', 'CANCER_TYPE',
#        'CANCER_TYPE_DETAILED', 'MUTATION_COUNT', 'ONCOTREE_CODE',
#        'SOMATIC_STATUS', 'TMB_NONSYNONYMOUS', 'SAMPLE_COUNT'],
#       dtype='object', name='clinicalAttributeId')
# clinicalAttributeId patientId sampleId           studyId  \
# 0                     CLL_100  CLL_100  cllsll_icgc_2011
# 1                     CLL_110  CLL_110  cllsll_icgc_2011
# 2                     CLL_117  CLL_117  cllsll_icgc_2011
# 3                     CLL_124  CLL_124  cllsll_icgc_2011
# 4                      CLL_13   CLL_13  cllsll_icgc_2011
#
# clinicalAttributeId              CANCER_TYPE  \
# 0                    Mature B-Cell Neoplasms
# 1                    Mature B-Cell Neoplasms
# 2                    Mature B-Cell Neoplasms
# 3                    Mature B-Cell Neoplasms
# 4                    Mature B-Cell Neoplasms
#
# clinicalAttributeId                               CANCER_TYPE_DETAILED  \
# 0                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 1                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 2                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 3                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 4                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
#
# clinicalAttributeId MUTATION_COUNT ONCOTREE_CODE SOMATIC_STATUS  \
# 0                                6        CLLSLL        Matched
# 1                               10        CLLSLL        Matched
# 2                               11        CLLSLL        Matched
# 3                               11        CLLSLL        Matched
# 4                               13        CLLSLL        Matched
#
# clinicalAttributeId TMB_NONSYNONYMOUS SAMPLE_COUNT
# 0                                 0.2            1
# 1                      0.333333333333            1
# 2                      0.366666666667            1
# 3                      0.366666666667            1
# 4                      0.433333333333            1
# (1067, 35) Index(['alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 'chr',
#        'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
#        'driverTiersFilterAnnotation', 'endPosition', 'entrezGeneId', 'keyword',
#        'molecularProfileId', 'mutationStatus', 'mutationType',
#        'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
#        'patientId', 'proteinChange', 'proteinPosEnd', 'proteinPosStart',
#        'referenceAllele', 'refseqMrnaId', 'sampleId', 'startPosition',
#        'studyId', 'tumorAltCount', 'tumorRefCount', 'validationStatus',
#        'variantAllele', 'variantType', 'geneticEntityId', 'hugoGeneSymbol',
#        'type'],
#       dtype='object')
#   alleleSpecificCopyNumber aminoAcidChange  center chr driverFilter  \
# 0                     None            None  Oviedo  12         None
# 1                     None            None  Oviedo   1         None
# 2                     None            None  Oviedo  14         None
# 3                     None            None  Oviedo  17         None
# 4                     None            None  Oviedo   3         None
#
#   driverFilterAnnotation driverTiersFilter driverTiersFilterAnnotation  \
# 0                   None              None                        None
# 1                   None              None                        None
# 2                   None              None                        None
# 3                   None              None                        None
# 4                   None              None                        None
#
#    endPosition  entrezGeneId  ... startPosition           studyId  \
# 0      9021782        144568  ...       9021782  cllsll_icgc_2011
# 1    169391327         57821  ...     169391327  cllsll_icgc_2011
# 2     95660226         79789  ...      95660226  cllsll_icgc_2011
# 3     36002206         11056  ...      36002206  cllsll_icgc_2011
# 4     38141882          9940  ...      38141882  cllsll_icgc_2011
#
#   tumorAltCount tumorRefCount validationStatus variantAllele variantType  \
# 0          None          None               NA             G         SNP
# 1          None          None               NA             T         SNP
# 2          None          None               NA             T         SNP
# 3          None          None               NA             A         SNP
# 4          None          None               NA             A         SNP
#
#   geneticEntityId hugoGeneSymbol            type
# 0            None          A2ML1  protein-coding
# 1            None        CCDC181  protein-coding
# 2            None           CLMN  protein-coding
# 3            None          DDX52  protein-coding
# 4            None          DLEC1  protein-coding
#
# [5 rows x 35 columns]
# Data written to ../../data/cllsll_icgc_2011_clinical_data.csv
# Data written to ../../data/cllsll_icgc_2011_mutations.csv
# lcll_broad_2013
# (160, 10) Index(['patientId', 'sampleId', 'studyId', 'CANCER_TYPE',
#        'CANCER_TYPE_DETAILED', 'MUTATION_COUNT', 'ONCOTREE_CODE',
#        'SOMATIC_STATUS', 'TMB_NONSYNONYMOUS', 'SAMPLE_COUNT'],
#       dtype='object', name='clinicalAttributeId')
# clinicalAttributeId patientId sampleId          studyId  \
# 0                      CLL001   CLL001  lcll_broad_2013
# 1                      CLL003   CLL003  lcll_broad_2013
# 2                      CLL004   CLL004  lcll_broad_2013
# 3                      CLL005   CLL005  lcll_broad_2013
# 4                      CLL006   CLL006  lcll_broad_2013
#
# clinicalAttributeId              CANCER_TYPE  \
# 0                    Mature B-Cell Neoplasms
# 1                    Mature B-Cell Neoplasms
# 2                    Mature B-Cell Neoplasms
# 3                    Mature B-Cell Neoplasms
# 4                    Mature B-Cell Neoplasms
#
# clinicalAttributeId                               CANCER_TYPE_DETAILED  \
# 0                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 1                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 2                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 3                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 4                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
#
# clinicalAttributeId MUTATION_COUNT ONCOTREE_CODE SOMATIC_STATUS  \
# 0                               13        CLLSLL        Matched
# 1                               14        CLLSLL        Matched
# 2                               12        CLLSLL        Matched
# 3                               19        CLLSLL        Matched
# 4                               29        CLLSLL        Matched
#
# clinicalAttributeId TMB_NONSYNONYMOUS SAMPLE_COUNT
# 0                      0.433333333333            1
# 1                      0.466666666667            1
# 2                                 0.4            1
# 3                      0.633333333333            1
# 4                      0.966666666667            1
# (2312, 35) Index(['alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 'chr',
#        'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
#        'driverTiersFilterAnnotation', 'endPosition', 'entrezGeneId', 'keyword',
#        'molecularProfileId', 'mutationStatus', 'mutationType',
#        'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
#        'patientId', 'proteinChange', 'proteinPosEnd', 'proteinPosStart',
#        'referenceAllele', 'refseqMrnaId', 'sampleId', 'startPosition',
#        'studyId', 'tumorAltCount', 'tumorRefCount', 'validationStatus',
#        'variantAllele', 'variantType', 'geneticEntityId', 'hugoGeneSymbol',
#        'type'],
#       dtype='object')
#   alleleSpecificCopyNumber aminoAcidChange         center chr driverFilter  \
# 0                     None            None  broad.mit.edu   3         None
# 1                     None            None  broad.mit.edu  12         None
# 2                     None            None  broad.mit.edu  12         None
# 3                     None            None  broad.mit.edu   2         None
# 4                     None            None  broad.mit.edu   3         None
#
#   driverFilterAnnotation driverTiersFilter driverTiersFilterAnnotation  \
# 0                   None              None                        None
# 1                   None              None                        None
# 2                   None              None                        None
# 3                   None              None                        None
# 4                   None              None                        None
#
#    endPosition  entrezGeneId  ... startPosition          studyId  \
# 0     38182641          4615  ...      38182641  lcll_broad_2013
# 1     86373542         25834  ...      86373542  lcll_broad_2013
# 2     76741541         79738  ...      76741541  lcll_broad_2013
# 3     56419944        114800  ...      56419944  lcll_broad_2013
# 4     52812956          3697  ...      52812956  lcll_broad_2013
#
#   tumorAltCount tumorRefCount validationStatus variantAllele variantType  \
# 0          None          None               NA             C         SNP
# 1          None          None               NA             A         SNP
# 2          None          None               NA             C         SNP
# 3          None          None               NA             G         SNP
# 4          None          None               NA             T         SNP
#
#   geneticEntityId hugoGeneSymbol            type
# 0            None          MYD88  protein-coding
# 1            None         MGAT4C  protein-coding
# 2            None          BBS10  protein-coding
# 3            None        CCDC85A  protein-coding
# 4            None          ITIH1  protein-coding
#
# [5 rows x 35 columns]
# Data written to ../../data/lcll_broad_2013_clinical_data.csv
# Data written to ../../data/lcll_broad_2013_mutations.csv
# cll_iuopa_2015
# (506, 16) Index(['patientId', 'sampleId', 'studyId', 'CANCER_TYPE',
#        'CANCER_TYPE_DETAILED', 'EXOME_CAPTURE', 'IGHV_GENE', 'IGHV_IDENTITY',
#        'IGHV_MUTATED', 'MUTATION_COUNT', 'ONCOTREE_CODE', 'PLATFORM',
#        'SOMATIC_STATUS', 'TMB_NONSYNONYMOUS', 'EPIGENETIC', 'SAMPLE_COUNT'],
#       dtype='object', name='clinicalAttributeId')
# clinicalAttributeId            patientId             sampleId         studyId  \
# 0                       cll_iuopa_2015_1     cll_iuopa_2015_1  cll_iuopa_2015
# 1                      cll_iuopa_2015_10    cll_iuopa_2015_10  cll_iuopa_2015
# 2                     cll_iuopa_2015_100   cll_iuopa_2015_100  cll_iuopa_2015
# 3                    cll_iuopa_2015_1047  cll_iuopa_2015_1047  cll_iuopa_2015
# 4                    cll_iuopa_2015_1050  cll_iuopa_2015_1050  cll_iuopa_2015
#
# clinicalAttributeId              CANCER_TYPE  \
# 0                    Mature B-Cell Neoplasms
# 1                    Mature B-Cell Neoplasms
# 2                    Mature B-Cell Neoplasms
# 3                    Mature B-Cell Neoplasms
# 4                    Mature B-Cell Neoplasms
#
# clinicalAttributeId                               CANCER_TYPE_DETAILED  \
# 0                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 1                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 2                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 3                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 4                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
#
# clinicalAttributeId                          EXOME_CAPTURE IGHV_GENE  \
# 0                                SureSelect Human All Exon   IGHV1-3
# 1                       SureSelect XT Human All Exon 50 Mb  IGHV3-21
# 2                       SureSelect XT Human All Exon 50 Mb  IGHV1-69
# 3                    SureSelect XT2 Human All Exon v4+UTRs  IGHV4-59
# 4                    SureSelect XT2 Human All Exon v4+UTRs  IGHV1-69
#
# clinicalAttributeId IGHV_IDENTITY IGHV_MUTATED MUTATION_COUNT ONCOTREE_CODE  \
# 0                             100        UNMUT             12        CLLSLL
# 1                            99.6        UNMUT             23        CLLSLL
# 2                             100        UNMUT              7        CLLSLL
# 3                           97.19          MUT              8        CLLSLL
# 4                             100        UNMUT             13        CLLSLL
#
# clinicalAttributeId PLATFORM SOMATIC_STATUS TMB_NONSYNONYMOUS  \
# 0                    WES,WGS        Matched               0.4
# 1                    WES,WGS        Matched    0.766666666667
# 2                        WES        Matched    0.233333333333
# 3                        WES        Matched    0.266666666667
# 4                        WES        Matched    0.433333333333
#
# clinicalAttributeId        EPIGENETIC SAMPLE_COUNT
# 0                      Naive-like CLL            1
# 1                    Intermediate CLL            1
# 2                      Naive-like CLL            1
# 3                     Memory-like CLL            1
# 4                      Naive-like CLL            1
# (7134, 35) Index(['alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 'chr',
#        'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
#        'driverTiersFilterAnnotation', 'endPosition', 'entrezGeneId', 'keyword',
#        'molecularProfileId', 'mutationStatus', 'mutationType',
#        'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
#        'patientId', 'proteinChange', 'proteinPosEnd', 'proteinPosStart',
#        'referenceAllele', 'refseqMrnaId', 'sampleId', 'startPosition',
#        'studyId', 'tumorAltCount', 'tumorRefCount', 'validationStatus',
#        'variantAllele', 'variantType', 'geneticEntityId', 'hugoGeneSymbol',
#        'type'],
#       dtype='object')
#   alleleSpecificCopyNumber aminoAcidChange                   center chr  \
# 0                     None            None  www.unioviedo.es/IUOPA/  19
# 1                     None            None  www.unioviedo.es/IUOPA/   3
# 2                     None            None  www.unioviedo.es/IUOPA/   7
# 3                     None            None  www.unioviedo.es/IUOPA/   6
# 4                     None            None  www.unioviedo.es/IUOPA/  19
#
#   driverFilter driverFilterAnnotation driverTiersFilter  \
# 0         None                   None              None
# 1         None                   None              None
# 2         None                   None              None
# 3         None                   None              None
# 4         None                   None              None
#
#   driverTiersFilterAnnotation  endPosition  entrezGeneId  ... startPosition  \
# 0                        None     54646887          4849  ...      54646887
# 1                        None     78700896          6091  ...      78700896
# 2                        None     20778606        340273  ...      20778606
# 3                        None     71665885        135152  ...      71665885
# 4                        None     41383838          1549  ...      41383838
#
#           studyId tumorAltCount tumorRefCount validationStatus variantAllele  \
# 0  cll_iuopa_2015          None          None               NA             A
# 1  cll_iuopa_2015          None          None               NA             A
# 2  cll_iuopa_2015          None          None               NA             T
# 3  cll_iuopa_2015          None          None               NA             A
# 4  cll_iuopa_2015          None          None               NA             A
#
#   variantType geneticEntityId hugoGeneSymbol            type
# 0         SNP            None          CNOT3  protein-coding
# 1         SNP            None          ROBO1  protein-coding
# 2         SNP            None          ABCB5  protein-coding
# 3         SNP            None         B3GAT2  protein-coding
# 4         SNP            None         CYP2A7  protein-coding
#
# [5 rows x 35 columns]
# Data written to ../../data/cll_iuopa_2015_clinical_data.csv
# Data written to ../../data/cll_iuopa_2015_mutations.csv
# cll_broad_2015
# (537, 14) Index(['patientId', 'sampleId', 'studyId', 'CANCER_TYPE',
#        'CANCER_TYPE_DETAILED', 'CAPTURE_BAIT_SET', 'IGHV_GENE',
#        'MUTATION_COUNT', 'ONCOTREE_CODE', 'SOMATIC_STATUS',
#        'TMB_NONSYNONYMOUS', 'COHORT', 'PRIOR_TREATMENT', 'SAMPLE_COUNT'],
#       dtype='object', name='clinicalAttributeId')
# clinicalAttributeId      patientId                      sampleId  \
# 0                    CLL-GCLL-0001  CLL-GCLL-0001-Tumor-SM-41JLZ
# 1                    CLL-GCLL-0002  CLL-GCLL-0002-Tumor-SM-41JM1
# 2                    CLL-GCLL-0003  CLL-GCLL-0003-Tumor-SM-41JM2
# 3                    CLL-GCLL-0004  CLL-GCLL-0004-Tumor-SM-41JM3
# 4                    CLL-GCLL-0006  CLL-GCLL-0006-Tumor-SM-41JM5
#
# clinicalAttributeId         studyId              CANCER_TYPE  \
# 0                    cll_broad_2015  Mature B-Cell Neoplasms
# 1                    cll_broad_2015  Mature B-Cell Neoplasms
# 2                    cll_broad_2015  Mature B-Cell Neoplasms
# 3                    cll_broad_2015  Mature B-Cell Neoplasms
# 4                    cll_broad_2015  Mature B-Cell Neoplasms
#
# clinicalAttributeId                               CANCER_TYPE_DETAILED  \
# 0                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 1                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 2                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 3                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
# 4                    Chronic Lymphocytic Leukemia/Small Lymphocytic...
#
# clinicalAttributeId                                CAPTURE_BAIT_SET IGHV_GENE  \
# 0                    whole_exome_agilent_1.1_refseq_plus_3_boosters   mutated
# 1                    whole_exome_agilent_1.1_refseq_plus_3_boosters   mutated
# 2                    whole_exome_agilent_1.1_refseq_plus_3_boosters   mutated
# 3                    whole_exome_agilent_1.1_refseq_plus_3_boosters   mutated
# 4                    whole_exome_agilent_1.1_refseq_plus_3_boosters   mutated
#
# clinicalAttributeId MUTATION_COUNT ONCOTREE_CODE SOMATIC_STATUS  \
# 0                                8        CLLSLL        Matched
# 1                               12        CLLSLL        Matched
# 2                               14        CLLSLL        Matched
# 3                                9        CLLSLL        Matched
# 4                               13        CLLSLL        Matched
#
# clinicalAttributeId TMB_NONSYNONYMOUS       COHORT  PRIOR_TREATMENT  \
# 0                      0.266666666667  GCLLSG_CLL8  treatment naive
# 1                                 0.4  GCLLSG_CLL8  treatment naive
# 2                      0.466666666667  GCLLSG_CLL8  treatment naive
# 3                                 0.3  GCLLSG_CLL8  treatment naive
# 4                                 0.4  GCLLSG_CLL8  treatment naive
#
# clinicalAttributeId SAMPLE_COUNT
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
# (9487, 35) Index(['alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 'chr',
#        'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
#        'driverTiersFilterAnnotation', 'endPosition', 'entrezGeneId', 'keyword',
#        'molecularProfileId', 'mutationStatus', 'mutationType',
#        'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
#        'patientId', 'proteinChange', 'proteinPosEnd', 'proteinPosStart',
#        'referenceAllele', 'refseqMrnaId', 'sampleId', 'startPosition',
#        'studyId', 'tumorAltCount', 'tumorRefCount', 'validationStatus',
#        'variantAllele', 'variantType', 'geneticEntityId', 'hugoGeneSymbol',
#        'type'],
#       dtype='object')
#   alleleSpecificCopyNumber aminoAcidChange         center chr driverFilter  \
# 0                     None            None  broad.mit.edu   6         None
# 1                     None            None  broad.mit.edu   1         None
# 2                     None            None  broad.mit.edu  20         None
# 3                     None            None  broad.mit.edu   2         None
# 4                     None            None  broad.mit.edu   1         None
#
#   driverFilterAnnotation driverTiersFilter driverTiersFilterAnnotation  \
# 0                   None              None                        None
# 1                   None              None                        None
# 2                   None              None                        None
# 3                   None              None                        None
# 4                   None              None                        None
#
#    endPosition  entrezGeneId  ... startPosition         studyId tumorAltCount  \
# 0    129802568          3908  ...     129802568  cll_broad_2015            63
# 1    120438518         11085  ...     120438518  cll_broad_2015             4
# 2      4229250           146  ...       4229250  cll_broad_2015            14
# 3    196799323         56171  ...     196799323  cll_broad_2015            78
# 4    228612633          8290  ...     228612633  cll_broad_2015            43
#
#   tumorRefCount validationStatus variantAllele variantType geneticEntityId  \
# 0            97               NA             A         SNP            None
# 1           116               NA             A         SNP            None
# 2            24               NA             A         SNP            None
# 3           105               NA             C         SNP            None
# 4            34               NA             A         SNP            None
#
#   hugoGeneSymbol            type
# 0          LAMA2  protein-coding
# 1         ADAM30  protein-coding
# 2         ADRA1D  protein-coding
# 3          DNAH7  protein-coding
# 4           H3-4  protein-coding
#
# [5 rows x 35 columns]
# Data written to ../../data/cll_broad_2015_clinical_data.csv
# Data written to ../../data/cll_broad_2015_mutations.csv
# cll_broad_2022
# (1154, 43) Index(['patientId', 'sampleId', 'studyId', 'ARRAY450K', 'CANCER_TYPE',
#        'CANCER_TYPE_DETAILED', 'CENTER', 'CLL_EPITYPE', 'DISEASE_TYPE',
#        'EC_DISCOVERY', 'EC_EXTENSION', 'IGLV3_21_R110', 'M-CLL_WES',
#        'MUTATION_COUNT', 'NORMAL_MEAN_COVERAGE', 'ONCOTREE_CODE',
#        'RNA_SEQUENCING', 'RRBS', 'SEQUENCING_PLATFORM', 'SOMATIC_STATUS',
#        'TMB_NONSYNONYMOUS', 'TUMOR_MEAN_COVERAGE', 'TUMOR_MOLECULAR_SUBTYPE',
#        'TUMOR_SAMPLE_PLOIDY', 'TUMOR_SAMPLE_PURITY', 'U-CLL_WES', 'U1_STATUS',
#        'AGE', 'AGE_SAMPLING', 'COHORT', 'DEATH_DAYS', 'EXPRESSION_CLUSTER',
#        'FFS_MONTHS', 'FFS_STATUS', 'IGHV_IDENTITY_PERCENTAGE',
#        'IGHV_MUTATION_STATUS', 'OS_MONTHS', 'OS_STATUS',
#        'PRIOR_TREATMENT_CATEGORY', 'SAMPLE_COUNT', 'SEX',
#        'TREATMENT_AFTER_SAMPLING', 'TREATMENT_STATUS'],
#       dtype='object', name='clinicalAttributeId')
# clinicalAttributeId   patientId  sampleId         studyId ARRAY450K  \
# 0                    P-CRC-0001  CRC-0001  cll_broad_2022        No
# 1                    P-CRC-0002  CRC-0002  cll_broad_2022        No
# 2                    P-CRC-0003  CRC-0003  cll_broad_2022        No
# 3                    P-CRC-0004  CRC-0004  cll_broad_2022        No
# 4                    P-CRC-0005  CRC-0005  cll_broad_2022        No
#
# clinicalAttributeId              CANCER_TYPE  \
# 0                    Mature B-Cell Neoplasms
# 1                    Mature B-Cell Neoplasms
# 2                    Mature B-Cell Neoplasms
# 3                    Mature B-Cell Neoplasms
# 4                    Mature B-Cell Neoplasms
#
# clinicalAttributeId                               CANCER_TYPE_DETAILED CENTER  \
# 0                    Chronic Lymphocytic Leukemia/Small Lymphocytic...  Broad
# 1                    Chronic Lymphocytic Leukemia/Small Lymphocytic...  Broad
# 2                    Chronic Lymphocytic Leukemia/Small Lymphocytic...  Broad
# 3                    Chronic Lymphocytic Leukemia/Small Lymphocytic...  Broad
# 4                    Chronic Lymphocytic Leukemia/Small Lymphocytic...  Broad
#
# clinicalAttributeId CLL_EPITYPE DISEASE_TYPE EC_DISCOVERY  ... FFS_STATUS  \
# 0                         n-CLL          CLL          Yes  ...  1:Failure
# 1                         n-CLL          CLL          Yes  ...  1:Failure
# 2                         n-CLL          CLL          Yes  ...  1:Failure
# 3                         m-CLL          CLL          Yes  ...  1:Failure
# 4                         n-CLL          CLL          Yes  ...  1:Failure
#
# clinicalAttributeId IGHV_IDENTITY_PERCENTAGE IGHV_MUTATION_STATUS OS_MONTHS  \
# 0                                        100            unmutated    147.19
# 1                                        100            unmutated    154.49
# 2                                        100            unmutated     51.25
# 3                                      92.28              mutated    183.55
# 4                                        100            unmutated    164.35
#
# clinicalAttributeId   OS_STATUS PRIOR_TREATMENT_CATEGORY SAMPLE_COUNT     SEX  \
# 0                    1:DECEASED                Untreated            1  Female
# 1                    1:DECEASED                Untreated            1    Male
# 2                    1:DECEASED                Untreated            1  Female
# 3                      0:LIVING                Untreated            1    Male
# 4                      0:LIVING                Untreated            1    Male
#
# clinicalAttributeId TREATMENT_AFTER_SAMPLING TREATMENT_STATUS
# 0                                 Chemo + Ab    Pre-treatment
# 1                                 Chemo + Ab    Pre-treatment
# 2                                 Chemo + Ab    Pre-treatment
# 3                                 Chemo + Ab    Pre-treatment
# 4                                 Chemo + Ab    Pre-treatment
#
# [5 rows x 43 columns]
# (30229, 35) Index(['alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 'chr',
#        'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
#        'driverTiersFilterAnnotation', 'endPosition', 'entrezGeneId', 'keyword',
#        'molecularProfileId', 'mutationStatus', 'mutationType',
#        'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
#        'patientId', 'proteinChange', 'proteinPosEnd', 'proteinPosStart',
#        'referenceAllele', 'refseqMrnaId', 'sampleId', 'startPosition',
#        'studyId', 'tumorAltCount', 'tumorRefCount', 'validationStatus',
#        'variantAllele', 'variantType', 'geneticEntityId', 'hugoGeneSymbol',
#        'type'],
#       dtype='object')
#   alleleSpecificCopyNumber aminoAcidChange center chr driverFilter  \
# 0                     None            None  Broad   2         None
# 1                     None            None  Broad   2         None
# 2                     None            None  Broad  23         None
# 3                     None            None  Broad  12         None
# 4                     None            None  Broad   8         None
#
#   driverFilterAnnotation driverTiersFilter driverTiersFilterAnnotation  \
# 0                   None              None                        None
# 1                   None              None                        None
# 2                   None              None                        None
# 3                   None              None                        None
# 4                   None              None                        None
#
#    endPosition  entrezGeneId  ... startPosition         studyId tumorAltCount  \
# 0     98928394        200403  ...      98928394  cll_broad_2022             3
# 1    198267491         23451  ...     198267491  cll_broad_2022            35
# 2     83128311          1538  ...      83128311  cll_broad_2022             4
# 3     15654580          5800  ...      15654580  cll_broad_2022            38
# 4    139164553         51059  ...     139164553  cll_broad_2022             3
#
#   tumorRefCount validationStatus variantAllele  variantType  geneticEntityId  \
# 0            18               NA             A          SNP             None
# 1            27               NA             G          SNP             None
# 2            42               NA             C          SNP             None
# 3            35               NA             A          SNP             None
# 4            49               NA             A          SNP             None
#
#   hugoGeneSymbol            type
# 0          VWA3B  protein-coding
# 1          SF3B1  protein-coding
# 2          CYLC1  protein-coding
# 3          PTPRO  protein-coding
# 4        FAM135B  protein-coding
#
# [5 rows x 35 columns]
# Data written to ../../data/cll_broad_2022_clinical_data.csv
# Data written to ../../data/cll_broad_2022_mutations.csv

# %%
x = cbioportal.Clinical_Attributes.getAllClinicalAttributesInStudyUsingGET(
    studyId="cll_broad_2022",
    projection="DETAILED"
).result()

# %%
for i in x:
    # if not i.patientAttribute:
    print(i.clinicalAttributeId, i.description)
# Out:
# AGE Age at diagnosis
# AGE_SAMPLING Age at sampling
# ARRAY450K Sample included in 450K methylation array
# CANCER_TYPE Cancer Type
# CANCER_TYPE_DETAILED Cancer Type Detailed
# CENTER Sequencing center
# CLL_EPITYPE CLL epitype: naive-like (n-CLL), intermediate (i-CLL) and memory-like (m-CLL)
# COHORT Cohort
# DEATH_DAYS Death (days) from the date of sampling
# DISEASE_TYPE Disease type
# EC_DISCOVERY Sample included in expression cluster discovery set (1=yes, 0=no)
# EC_EXTENSION Sample included in expression cluster extension set (1=yes, 0=no)
# EXPRESSION_CLUSTER Expression cluster
# FFS_MONTHS Failure-free survival (months)
# FFS_STATUS Failure-free survival status
# IGHV_IDENTITY_PERCENTAGE Immunoglobulin genes mutation identity percentage
# IGHV_MUTATION_STATUS Immunoglobulin genes mutation status
# IGLV3_21_R110 IGLV3-21 R110 mutation status
# M-CLL_WES Sample included in M-CLL WES genetic candidate driver discovery cohort (1=yes, 0=no)
# MUTATION_COUNT Mutation Count
# NORMAL_MEAN_COVERAGE Normal Mean Coverage (WES)
# ONCOTREE_CODE Oncotree code
# OS_MONTHS Overall survival (months) from the date of the sequenced sample
# OS_STATUS Overall survival status from the date of the sequenced sample
# PRIOR_TREATMENT_CATEGORY Prior treatment category
# RNA_SEQUENCING Sample included in RNA-Sequencing
# RRBS Sample included in reduced representation bisulfite sequencing
# SAMPLE_COUNT Number of Samples Per Patient
# SEQUENCING_PLATFORM Sequencing platform
# SEX Sex
# SOMATIC_STATUS Somatic status
# TMB_NONSYNONYMOUS TMB (nonsynonymous)
# TREATMENT_AFTER_SAMPLING First treatment after sampling
# TREATMENT_STATUS Treatment status at sampling
# TUMOR_MEAN_COVERAGE Tumor mean coverage (WES)
# TUMOR_MOLECULAR_SUBTYPE Tumor molecular subtype: mutated IGHV (M-CLLs), unmutated IGHV (U-CLLs)
# TUMOR_SAMPLE_PLOIDY Tumor sample ploidy (WES)
# TUMOR_SAMPLE_PURITY Tumor sample purity (WES)
# U-CLL_WES Sample included in U-CLL WES genetic candidate driver discovery cohort (1=yes, 0=no)
# U1_STATUS Final U1 mutational status

# %%
studyId = "cll_broad_2022"
mutations = cbioportal.Mutations.getMutationsInMolecularProfileBySampleListIdUsingGET(
        molecularProfileId=f'{studyId}_mutations',
        sampleListId=f'{studyId}_all',
        projection='DETAILED'
    ).result()

# %%
mutations[0]
# Out:
# Mutation(alleleSpecificCopyNumber=None, aminoAcidChange=None, center='Broad', chr='2', driverFilter=None, driverFilterAnnotation=None, driverTiersFilter=None, driverTiersFilterAnnotation=None, endPosition=98928394, entrezGeneId=200403, gene=Gene(entrezGeneId=200403, geneticEntityId=None, hugoGeneSymbol='VWA3B', type='protein-coding'), keyword='VWA3B A1212 missense', molecularProfileId='cll_broad_2022_mutations', mutationStatus='NA', mutationType='Missense_Mutation', namespaceColumns=None, ncbiBuild='GRCh37', normalAltCount=0, normalRefCount=12, patientId='P-CRC-0001', proteinChange='A1212T', proteinPosEnd=1212, proteinPosStart=1212, referenceAllele='G', refseqMrnaId='NM_144992.4', sampleId='CRC-0001', startPosition=98928394, studyId='cll_broad_2022', tumorAltCount=3, tumorRefCount=18, uniquePatientKey='UC1DUkMtMDAwMTpjbGxfYnJvYWRfMjAyMg', uniqueSampleKey='Q1JDLTAwMDE6Y2xsX2Jyb2FkXzIwMjI', validationStatus='NA', variantAllele='A', variantType='SNP')
