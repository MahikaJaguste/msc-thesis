# %%
import pandas as pd
import json

# %%
filename = "../data/cbioportal/participants.4f6istp.tsv"

df = pd.read_csv(filename, sep = '\t')
df.head()
# Out:
#   participant_id cohort tumor_type tumor_molecular_subtype  gender     race  \
# 0       CRC-0001   UCSD        CLL                   U-CLL  female  unknown
# 1       CRC-0002   UCSD        CLL                   U-CLL    male  unknown
# 2       CRC-0003   UCSD        CLL                   U-CLL  female  unknown
# 3       CRC-0004   UCSD        CLL                   M-CLL    male  unknown
# 4       CRC-0005   UCSD        CLL                   U-CLL    male  unknown
#
#    age_at_diagnosis  age_at_reference_sample vital_status  \
# 0              44.0                       46         dead
# 1              55.0                       56         dead
# 2              63.0                       63         dead
# 3              51.0                       51        alive
# 4              36.0                       37        alive
#
#    death_days_from_samp  ... has_array_450k  set_mcll_wes  set_ucll_wes  \
# 0                4477.0  ...             No            No           Yes
# 1                4699.0  ...             No            No           Yes
# 2                1559.0  ...             No            No           Yes
# 3                   NaN  ...             No           Yes            No
# 4                   NaN  ...             No            No           Yes
#
#   set_rna_extension set_clinical_genomic_mcll  set_clinical_genomic_ucll  \
# 0                No                        No                        Yes
# 1                No                        No                        Yes
# 2                No                        No                        Yes
# 3                No                       Yes                         No
# 4                No                        No                        Yes
#
#   set_clinical_genomic_treatment_naive_mcll  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                       Yes
# 4                                        No
#
#   set_clinical_genomic_treatment_naive_ucll set_clinical_expression_clusters  \
# 0                                       Yes                              Yes
# 1                                       Yes                              Yes
# 2                                       Yes                              Yes
# 3                                        No                              Yes
# 4                                       Yes                              Yes
#
#   set_clinical_multiomic
# 0                    Yes
# 1                    Yes
# 2                    Yes
# 3                    Yes
# 4                    Yes
#
# [5 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 45 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   participant_id                             1009 non-null   object
#  1   cohort                                     1009 non-null   object
#  2   tumor_type                                 1009 non-null   object
#  3   tumor_molecular_subtype                    994 non-null    object
#  4   gender                                     1009 non-null   object
#  5   race                                       1009 non-null   object
#  6   age_at_diagnosis                           959 non-null    float64
#  7   age_at_reference_sample                    1009 non-null   int64
#  8   vital_status                               1009 non-null   object
#  9   death_days_from_samp                       286 non-null    float64
#  10  treatment_status_at_samp                   1009 non-null   object
#  11  rai_at_diagnosis                           209 non-null    float64
#  12  rai_at_sampling                            318 non-null    float64
#  13  prior_treatment_category                   1009 non-null   object
#  14  IGHV_mut                                   994 non-null    object
#  15  IGHV_identity                              991 non-null    float64
#  16  IGH_genes                                  975 non-null    object
#  17  Stereotype                                 947 non-null    object
#  18  IGL_expression                             997 non-null    object
#  19  IGL_genes                                  966 non-null    object
#  20  IGLV3-21_R110                              984 non-null    object
#  21  expression_cluster                         566 non-null    object
#  22  cll_epitype                                887 non-null    object
#  23  epicmit                                    887 non-null    float64
#  24  days_samp_to_diagnosis                     682 non-null    float64
#  25  days_samp_to_prior_treatment               67 non-null     float64
#  26  os_days                                    1009 non-null   int64
#  27  os                                         1009 non-null   int64
#  28  ffs_days                                   1009 non-null   int64
#  29  ffs                                        1009 non-null   int64
#  30  first_treatment_after_sample               397 non-null    object
#  31  has_wes                                    1009 non-null   object
#  32  has_wgs                                    1009 non-null   object
#  33  has_rna                                    1009 non-null   object
#  34  has_rrbs                                   1009 non-null   object
#  35  has_array_450k                             1009 non-null   object
#  36  set_mcll_wes                               1009 non-null   object
#  37  set_ucll_wes                               1009 non-null   object
#  38  set_rna_extension                          1009 non-null   object
#  39  set_clinical_genomic_mcll                  1009 non-null   object
#  40  set_clinical_genomic_ucll                  1009 non-null   object
#  41  set_clinical_genomic_treatment_naive_mcll  1009 non-null   object
#  42  set_clinical_genomic_treatment_naive_ucll  1009 non-null   object
#  43  set_clinical_expression_clusters           1009 non-null   object
#  44  set_clinical_multiomic                     1009 non-null   object
# dtypes: float64(8), int64(5), object(32)
# memory usage: 354.9+ KB

# %%
for col in df.columns:
    # print(f"{col}: {df[col].nunique()} unique values")
    if df[col].nunique() != 1:
        print(f"{col}: {df[col].nunique()} unique values")
# Out:
# participant_id: 1009 unique values
# cohort: 6 unique values
# tumor_molecular_subtype: 2 unique values
# gender: 2 unique values
# age_at_diagnosis: 58 unique values
# age_at_reference_sample: 63 unique values
# vital_status: 2 unique values
# death_days_from_samp: 271 unique values
# treatment_status_at_samp: 2 unique values
# rai_at_diagnosis: 5 unique values
# rai_at_sampling: 5 unique values
# prior_treatment_category: 6 unique values
# IGHV_mut: 2 unique values
# IGHV_identity: 241 unique values
# IGH_genes: 613 unique values
# Stereotype: 20 unique values
# IGL_expression: 4 unique values
# IGL_genes: 178 unique values
# IGLV3-21_R110: 2 unique values
# expression_cluster: 8 unique values
# cll_epitype: 4 unique values
# epicmit: 789 unique values
# days_samp_to_diagnosis: 578 unique values
# days_samp_to_prior_treatment: 66 unique values
# os_days: 877 unique values
# os: 2 unique values
# ffs_days: 874 unique values
# ffs: 2 unique values
# first_treatment_after_sample: 19 unique values
# has_wes: 2 unique values
# has_wgs: 2 unique values
# has_rna: 2 unique values
# has_rrbs: 2 unique values
# has_array_450k: 2 unique values
# set_mcll_wes: 2 unique values
# set_ucll_wes: 2 unique values
# set_rna_extension: 2 unique values
# set_clinical_genomic_mcll: 2 unique values
# set_clinical_genomic_ucll: 2 unique values
# set_clinical_genomic_treatment_naive_mcll: 2 unique values
# set_clinical_genomic_treatment_naive_ucll: 2 unique values
# set_clinical_expression_clusters: 2 unique values
# set_clinical_multiomic: 2 unique values

# %%
display(df['cohort'].value_counts())
display(df['prior_treatment_category'].value_counts())
display(df['cll_epitype'].value_counts())
# Out:
# cohort
# ICGC      448
# GCLLSG    278
# DFCI      172
# NHLBI      68
# MDACC      22
# UCSD       21
# Name: count, dtype: int64
# prior_treatment_category
# Untreated        920
# Chemo + Ab        37
# Chemo + no Ab     26
# Rel/Ref           22
# Ab + no Chemo      3
# LEN + Ab           1
# Name: count, dtype: int64
# cll_epitype
# n-CLL           391
# m-CLL           342
# i-CLL           141
# unclassified     13
# Name: count, dtype: int64

# %%
print(df['participant_id'])
# Out:
# 0        CRC-0001
# 1        CRC-0002
# 2        CRC-0003
# 3        CRC-0004
# 4        CRC-0005
#           ...
# 1004    SCLL-0502
# 1005    SCLL-0503
# 1006    SCLL-0504
# 1007    SCLL-0505
# 1008    SCLL-0506
# Name: participant_id, Length: 1009, dtype: object
