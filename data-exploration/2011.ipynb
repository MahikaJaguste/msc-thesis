# %%
import pandas as pd

# %%
filename = "../data/cbioportal/cllsll_icgc_2011_clinical_data.csv"

df = pd.read_csv(filename)
df.head()
# Out:
#   patientId sampleId           studyId              CANCER_TYPE  \
# 0   CLL_100  CLL_100  cllsll_icgc_2011  Mature B-Cell Neoplasms
# 1   CLL_110  CLL_110  cllsll_icgc_2011  Mature B-Cell Neoplasms
# 2   CLL_117  CLL_117  cllsll_icgc_2011  Mature B-Cell Neoplasms
# 3   CLL_124  CLL_124  cllsll_icgc_2011  Mature B-Cell Neoplasms
# 4    CLL_13   CLL_13  cllsll_icgc_2011  Mature B-Cell Neoplasms
#
#                                 CANCER_TYPE_DETAILED  MUTATION_COUNT  \
# 0  Chronic Lymphocytic Leukemia/Small Lymphocytic...               6
# 1  Chronic Lymphocytic Leukemia/Small Lymphocytic...              10
# 2  Chronic Lymphocytic Leukemia/Small Lymphocytic...              11
# 3  Chronic Lymphocytic Leukemia/Small Lymphocytic...              11
# 4  Chronic Lymphocytic Leukemia/Small Lymphocytic...              13
#
#   ONCOTREE_CODE SOMATIC_STATUS  TMB_NONSYNONYMOUS  SAMPLE_COUNT
# 0        CLLSLL        Matched           0.200000             1
# 1        CLLSLL        Matched           0.333333             1
# 2        CLLSLL        Matched           0.366667             1
# 3        CLLSLL        Matched           0.366667             1
# 4        CLLSLL        Matched           0.433333             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patientId             105 non-null    object
#  1   sampleId              105 non-null    object
#  2   studyId               105 non-null    object
#  3   CANCER_TYPE           105 non-null    object
#  4   CANCER_TYPE_DETAILED  105 non-null    object
#  5   MUTATION_COUNT        105 non-null    int64
#  6   ONCOTREE_CODE         105 non-null    object
#  7   SOMATIC_STATUS        105 non-null    object
#  8   TMB_NONSYNONYMOUS     105 non-null    float64
#  9   SAMPLE_COUNT          105 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 8.3+ KB

# %%
for col in df.columns:
    # print(f"{col}: {df[col].nunique()} unique values")
    if df[col].nunique() != 1:
        print(f"{col}: {df[col].nunique()} unique values")
# Out:
# patientId: 105 unique values
# sampleId: 105 unique values
# MUTATION_COUNT: 21 unique values
# TMB_NONSYNONYMOUS: 20 unique values

# %%
filename = "../data/cbioportal/cllsll_icgc_2011_mutations.csv"

mutation_df = pd.read_csv(filename)
mutation_df.head()
# Out:
#    center  chr  endPosition  entrezGeneId                keyword  \
# 0  Oviedo   12      9021782        144568   A2ML1 N1402 missense
# 1  Oviedo    1    169391327         57821  CCDC181 D114 missense
# 2  Oviedo   14     95660226         79789     CLMN A934 missense
# 3  Oviedo   17     36002206         11056     DDX52 K73 missense
# 4  Oviedo    3     38141882          9940    DLEC1 V944 missense
#
#            molecularProfileId  mutationStatus       mutationType ncbiBuild  \
# 0  cllsll_icgc_2011_mutations             NaN  Missense_Mutation    GRCh37
# 1  cllsll_icgc_2011_mutations             NaN  Missense_Mutation    GRCh37
# 2  cllsll_icgc_2011_mutations             NaN  Missense_Mutation    GRCh37
# 3  cllsll_icgc_2011_mutations             NaN  Missense_Mutation    GRCh37
# 4  cllsll_icgc_2011_mutations             NaN  Missense_Mutation    GRCh37
#
#   patientId  ... referenceAllele  refseqMrnaId  sampleId startPosition  \
# 0   CLL_375  ...               A   NM_144670.4   CLL_375       9021782
# 1   CLL_375  ...               G           NaN   CLL_375     169391327
# 2   CLL_375  ...               C   NM_024734.3   CLL_375      95660226
# 3   CLL_375  ...               T   NM_007010.3   CLL_375      36002206
# 4   CLL_375  ...               G           NaN   CLL_375      38141882
#
#             studyId validationStatus  variantAllele variantType  \
# 0  cllsll_icgc_2011              NaN              G         SNP
# 1  cllsll_icgc_2011              NaN              T         SNP
# 2  cllsll_icgc_2011              NaN              T         SNP
# 3  cllsll_icgc_2011              NaN              A         SNP
# 4  cllsll_icgc_2011              NaN              A         SNP
#
#    hugoGeneSymbol            type
# 0           A2ML1  protein-coding
# 1         CCDC181  protein-coding
# 2            CLMN  protein-coding
# 3           DDX52  protein-coding
# 4           DLEC1  protein-coding
#
# [5 rows x 23 columns]
