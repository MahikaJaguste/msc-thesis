# %%
import pandas as pd

# %%
filename = "../data/cbioportal/lcll_broad_2013_clinical_data.csv"

df = pd.read_csv(filename)
df.head()
# Out:
#   patientId sampleId          studyId              CANCER_TYPE  \
# 0    CLL001   CLL001  lcll_broad_2013  Mature B-Cell Neoplasms
# 1    CLL003   CLL003  lcll_broad_2013  Mature B-Cell Neoplasms
# 2    CLL004   CLL004  lcll_broad_2013  Mature B-Cell Neoplasms
# 3    CLL005   CLL005  lcll_broad_2013  Mature B-Cell Neoplasms
# 4    CLL006   CLL006  lcll_broad_2013  Mature B-Cell Neoplasms
#
#                                 CANCER_TYPE_DETAILED  MUTATION_COUNT  \
# 0  Chronic Lymphocytic Leukemia/Small Lymphocytic...              13
# 1  Chronic Lymphocytic Leukemia/Small Lymphocytic...              14
# 2  Chronic Lymphocytic Leukemia/Small Lymphocytic...              12
# 3  Chronic Lymphocytic Leukemia/Small Lymphocytic...              19
# 4  Chronic Lymphocytic Leukemia/Small Lymphocytic...              29
#
#   ONCOTREE_CODE SOMATIC_STATUS  TMB_NONSYNONYMOUS  SAMPLE_COUNT
# 0        CLLSLL        Matched           0.433333             1
# 1        CLLSLL        Matched           0.466667             1
# 2        CLLSLL        Matched           0.400000             1
# 3        CLLSLL        Matched           0.633333             1
# 4        CLLSLL        Matched           0.966667             1

# %%
df.tail()
# Out:
#     patientId sampleId          studyId              CANCER_TYPE  \
# 155    CLL166   CLL166  lcll_broad_2013  Mature B-Cell Neoplasms
# 156    CLL167   CLL167  lcll_broad_2013  Mature B-Cell Neoplasms
# 157    CLL168   CLL168  lcll_broad_2013  Mature B-Cell Neoplasms
# 158    CLL169   CLL169  lcll_broad_2013  Mature B-Cell Neoplasms
# 159    CLL170   CLL170  lcll_broad_2013  Mature B-Cell Neoplasms
#
#                                   CANCER_TYPE_DETAILED  MUTATION_COUNT  \
# 155  Chronic Lymphocytic Leukemia/Small Lymphocytic...               8
# 156  Chronic Lymphocytic Leukemia/Small Lymphocytic...              14
# 157  Chronic Lymphocytic Leukemia/Small Lymphocytic...              15
# 158  Chronic Lymphocytic Leukemia/Small Lymphocytic...              17
# 159  Chronic Lymphocytic Leukemia/Small Lymphocytic...               0
#
#     ONCOTREE_CODE SOMATIC_STATUS  TMB_NONSYNONYMOUS  SAMPLE_COUNT
# 155        CLLSLL        Matched           0.266667             1
# 156        CLLSLL        Matched           0.466667             1
# 157        CLLSLL        Matched           0.500000             1
# 158        CLLSLL        Matched           0.566667             1
# 159        CLLSLL        Matched           0.000000             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   patientId             160 non-null    object
#  1   sampleId              160 non-null    object
#  2   studyId               160 non-null    object
#  3   CANCER_TYPE           160 non-null    object
#  4   CANCER_TYPE_DETAILED  160 non-null    object
#  5   MUTATION_COUNT        160 non-null    int64
#  6   ONCOTREE_CODE         160 non-null    object
#  7   SOMATIC_STATUS        160 non-null    object
#  8   TMB_NONSYNONYMOUS     160 non-null    float64
#  9   SAMPLE_COUNT          160 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 12.6+ KB

# %%
for col in df.columns:
    # print(f"{col}: {df[col].nunique()} unique values")
    if df[col].nunique() != 1:
        print(f"{col}: {df[col].nunique()} unique values")
# Out:
# patientId: 160 unique values
# sampleId: 160 unique values
# MUTATION_COUNT: 32 unique values
# TMB_NONSYNONYMOUS: 32 unique values

# %%
filename = "../data/cbioportal/lcll_broad_2013_mutations.csv"

mutation_df = pd.read_csv(filename)
mutation_df.head()
# Out:
#           center  chr  endPosition  entrezGeneId               keyword  \
# 0  broad.mit.edu    3     38182641          4615   MYD88 L265 missense
# 1  broad.mit.edu   12     86373542         25834  MGAT4C T321 missense
# 2  broad.mit.edu   12     76741541         79738    BBS10 H75 missense
# 3  broad.mit.edu    2     56419944        114800    CCDC85A truncating
# 4  broad.mit.edu    3     52812956          3697      ITIH1 truncating
#
#           molecularProfileId mutationStatus       mutationType ncbiBuild  \
# 0  lcll_broad_2013_mutations        Somatic  Missense_Mutation    GRCh37
# 1  lcll_broad_2013_mutations        Somatic  Missense_Mutation    GRCh37
# 2  lcll_broad_2013_mutations        Somatic  Missense_Mutation    GRCh37
# 3  lcll_broad_2013_mutations        Somatic  Nonsense_Mutation    GRCh37
# 4  lcll_broad_2013_mutations        Somatic        Splice_Site    GRCh37
#
#   patientId  ... referenceAllele    refseqMrnaId  sampleId startPosition  \
# 0    CLL025  ...               T     NM_002468.4    CLL025      38182641
# 1    CLL025  ...               G             NaN    CLL025      86373542
# 2    CLL025  ...               T     NM_024685.3    CLL025      76741541
# 3    CLL025  ...               C  NM_001080433.1    CLL025      56419944
# 4    CLL025  ...               A     NM_002215.3    CLL025      52812956
#
#            studyId validationStatus  variantAllele variantType  \
# 0  lcll_broad_2013              NaN              C         SNP
# 1  lcll_broad_2013              NaN              A         SNP
# 2  lcll_broad_2013              NaN              C         SNP
# 3  lcll_broad_2013              NaN              G         SNP
# 4  lcll_broad_2013              NaN              T         SNP
#
#    hugoGeneSymbol            type
# 0           MYD88  protein-coding
# 1          MGAT4C  protein-coding
# 2           BBS10  protein-coding
# 3         CCDC85A  protein-coding
# 4           ITIH1  protein-coding
#
# [5 rows x 23 columns]
